# %% [markdown]
# <a href="https://colab.research.google.com/github/oreushka/SIA_lab1.1/blob/main/Month1_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание 1 (numpy + matplotlib)

# %% [markdown]
# ---

# %% [markdown]
# Напишите программу, которая будет решать систему линейных уравнений вида:
#
# \begin{matrix} a_{11}x+a_{12}y=b_{1}&(1) \\ a_{21}x+a_{22}y=b_{2} &(2) \end{matrix}
# ​
# * На вход программа должна принимать 2 строки (т.е. должен быть реализован ввод с клавиатуры). Каждая строка содержит 3 действительных числа через пробел: коэффициенты a и b.
# * Систему уравнений необходимо решить ДВУМЯ способами: матричным и графическим. Для матричного способа программа должна выдавать значения x и y в одну строку через пробел. Для графического - график, на котором отмечены решения, если они есть.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([input().split(), input().split()])

#метод Крамера
b = np.array([[a[0][0], a[0][1]], [a[1][0], a[1][1]]], dtype=np.float64)
v = np.array([a[0][2], a[1][2]], dtype=np.float64)
u = np.linalg.solve(b, v)
print(u)

#График
fig = plt.subplots()
x = np.linspace(float(u[0])-5, float(u[0])+5, 10)

y = (float(a[0][2]) - float(a[0][0])*x)/float(a[0][1])
y1 = (float(a[1][2]) - float(a[1][0])*x)/float(a[1][1])

plt.plot(x, y)
plt.plot(x, y1)
plt.show()
# Out:
# 0.6688 0.369 8
# 0.23 0.1599 65
# [-1028.75613018  1886.2658533 ]

# %% [markdown]
# # Задание 2 (pytorch + matplotlib)

# %% [markdown]
# Пусть $f(x) = \sin(x) * x$. Постройте график $f(x)$ и $\frac{df(x)}{dx}$, используя пакет autograd из pyTorch для расчета производных и matplotlib для построения графиков.

# %%
import torch
from torch import autograd
import matplotlib.pyplot as plt

fig = plt.subplots()
x = torch.linspace(-5, 5, 100, requires_grad=True)
y = torch.sin(x)*x
y.backward(x)

plt.plot(x.detach().numpy(), x.detach().numpy(), label='sin(x)*x')
plt.plot(x.detach().numpy(), x.grad.detach().numpy(), label='grad')
plt.legend()
